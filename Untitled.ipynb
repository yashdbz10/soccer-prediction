# %%
import sqlite3
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error 
from math import sqrt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
cnx = sqlite3.connect('database.sqlite')
df = pd.read_sql_query("SELECT * FROM Player_Attributes", cnx)

# %%
df.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
df.shape
# Out:
# (183978, 42)

# %%
df.isnull().sum()
# Out:
# id                        0
# player_fifa_api_id        0
# player_api_id             0
# date                      0
# overall_rating          836
# potential               836
# preferred_foot          836
# attacking_work_rate    3230
# defensive_work_rate     836
# crossing                836
# finishing               836
# heading_accuracy        836
# short_passing           836
# volleys                2713
# dribbling               836
# curve                  2713
# free_kick_accuracy      836
# long_passing            836
# ball_control            836
# acceleration            836
# sprint_speed            836
# agility                2713
# reactions               836
# balance                2713
# shot_power              836
# jumping                2713
# stamina                 836
# strength                836
# long_shots              836
# aggression              836
# interceptions           836
# positioning             836
# vision                 2713
# ...

# %%
df.columns
# Out:
# Index(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating',
#        'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   183978 non-null  int64
#  1   player_fifa_api_id   183978 non-null  int64
#  2   player_api_id        183978 non-null  int64
#  3   date                 183978 non-null  object
#  4   overall_rating       183142 non-null  float64
#  5   potential            183142 non-null  float64
#  6   preferred_foot       183142 non-null  object
#  7   attacking_work_rate  180748 non-null  object
#  8   defensive_work_rate  183142 non-null  object
#  9   crossing             183142 non-null  float64
#  10  finishing            183142 non-null  float64
#  11  heading_accuracy     183142 non-null  float64
#  12  short_passing        183142 non-null  float64
#  13  volleys              181265 non-null  float64
# ...

# %%
f,ax = plt.subplots(figsize=(25, 15))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="red", fmt= '.1f',ax=ax)
plt.show()

# %%
to_impute_by_mean = df.loc[:, [ 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
       'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
       'gk_reflexes']]
for i in to_impute_by_mean.columns:
    df[i].fillna(df[i].mean(), inplace = True)

# %%
to_impute_by_mode = df.loc[:, ['preferred_foot', 'attacking_work_rate','defensive_work_rate']]
for i in to_impute_by_mode.columns:
    df[i].fillna(df[i].mode()[0], inplace = True)

# %%
to_impute_by_median = df.loc[:, ['overall_rating', 'potential']]
for i in to_impute_by_median.columns:
    df[i].fillna(df[i].median(), inplace = True)

# %%
df.columns[df.isna().any()]
# Out:
# Index([], dtype='object')

# %%
df.describe()
# Out:
#                  id  player_fifa_api_id  player_api_id  overall_rating  \
# count  183978.00000       183978.000000  183978.000000   183978.000000
# mean    91989.50000       165671.524291  135900.617324       68.601833
# std     53110.01825        53851.094769  136927.840510        7.025175
# min         1.00000            2.000000    2625.000000       33.000000
# 25%     45995.25000       155798.000000   34763.000000       64.000000
# 50%     91989.50000       183488.000000   77741.000000       69.000000
# 75%    137983.75000       199848.000000  191080.000000       73.000000
# max    183978.00000       234141.000000  750584.000000       94.000000
#
#            potential       crossing      finishing  heading_accuracy  \
# count  183978.000000  183978.000000  183978.000000     183978.000000
# mean       73.462805      55.086883      49.921078         57.266023
# std         6.577376      17.202916      18.995399         16.451399
# ...

# %%
df.isnull().sum()
# Out:
# id                     0
# player_fifa_api_id     0
# player_api_id          0
# date                   0
# overall_rating         0
# potential              0
# preferred_foot         0
# attacking_work_rate    0
# defensive_work_rate    0
# crossing               0
# finishing              0
# heading_accuracy       0
# short_passing          0
# volleys                0
# dribbling              0
# curve                  0
# free_kick_accuracy     0
# long_passing           0
# ball_control           0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# long_shots             0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# ...

# %%
plt.figure(figsize = (18, 8))
plt.style.use('fivethirtyeight')
ax = sns.countplot( data = df, palette = 'dark')
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 16)
ax.set_title(label = 'Comparison of Positions and Players', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (25, 10)
sns.boxplot(data = df, palette = 'inferno')
# Out:
# <AxesSubplot:>

# %%
df_new=df.drop(['id','player_fifa_api_id','player_api_id','date'],axis=1)
df_new.head()
# Out:
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
pd.get_dummies(df_new).shape
# Out:
# (183978, 64)

# %%
len(df_new['preferred_foot'].unique())
# Out:
# 2

# %%
len(df_new['attacking_work_rate'].unique())
# Out:
# 8

# %%
len(df_new['defensive_work_rate'].unique())
# Out:
# 19

# %%
df_map=df_new.preferred_foot.value_counts().to_dict()
df_map
# Out:
# {'right': 139245, 'left': 44733}

# %%
df_map1=df_new.attacking_work_rate.value_counts().to_dict()
df_map1
# Out:
# {'medium': 128300,
#  'high': 42823,
#  'low': 8569,
#  'None': 3639,
#  'norm': 348,
#  'y': 106,
#  'le': 104,
#  'stoc': 89}

# %%
df_map2=df_new.defensive_work_rate.value_counts().to_dict()
df_map2
# Out:
# {'medium': 131682,
#  'high': 27041,
#  'low': 18432,
#  '_0': 2394,
#  'o': 1550,
#  '1': 441,
#  'ormal': 348,
#  '2': 342,
#  '3': 258,
#  '5': 234,
#  '7': 217,
#  '0': 197,
#  '6': 197,
#  '9': 152,
#  '4': 116,
#  'es': 106,
#  'ean': 104,
#  'tocky': 89,
#  '8': 78}

# %%
df_new.preferred_foot=df_new.preferred_foot.map(df_map)
df_new.head()
# Out:
#    overall_rating  potential  preferred_foot attacking_work_rate  \
# 0            67.0       71.0          139245              medium
# 1            67.0       71.0          139245              medium
# 2            62.0       66.0          139245              medium
# 3            61.0       65.0          139245              medium
# 4            61.0       65.0          139245              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
df_new.attacking_work_rate=df_new.attacking_work_rate.map(df_map1)
df_new.head()
# Out:
#    overall_rating  potential  preferred_foot  attacking_work_rate  \
# 0            67.0       71.0          139245               128300
# 1            67.0       71.0          139245               128300
# 2            62.0       66.0          139245               128300
# 3            61.0       65.0          139245               128300
# 4            61.0       65.0          139245               128300
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
df_new.defensive_work_rate=df_new.defensive_work_rate.map(df_map2)
df_new.head()
# Out:
#    overall_rating  potential  preferred_foot  attacking_work_rate  \
# 0            67.0       71.0          139245               128300
# 1            67.0       71.0          139245               128300
# 2            62.0       66.0          139245               128300
# 3            61.0       65.0          139245               128300
# 4            61.0       65.0          139245               128300
#
#    defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0               131682      49.0       44.0              71.0           61.0
# 1               131682      49.0       44.0              71.0           61.0
# 2               131682      49.0       44.0              71.0           61.0
# 3               131682      48.0       43.0              70.0           60.0
# 4               131682      48.0       43.0              70.0           60.0
#
#    volleys  ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
X = df_new.drop(columns = ['overall_rating'],axis=1)
y = df_new['overall_rating']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y, test_size= 0.33)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                      Coefficient
# potential               2.495495
# preferred_foot         -0.004484
# attacking_work_rate    -0.155144
# defensive_work_rate    -0.154079
# crossing                0.369620
# finishing               0.201399
# heading_accuracy        1.124533
# short_passing           0.722945
# volleys                 0.055830
# dribbling              -0.188255
# curve                   0.205873
# free_kick_accuracy      0.233840
# long_passing            0.101269
# ball_control            2.065276
# acceleration            0.074008
# sprint_speed            0.121034
# agility                -0.118883
# reactions               1.909443
# balance                 0.089388
# shot_power              0.249351
# jumping                 0.178166
# stamina                -0.081580
# strength                0.749471
# long_shots             -0.235366
# aggression              0.298277
# interceptions           0.223179
# positioning            -0.188841
# ...

# %%
predictions = lm.predict(x_test)
plt.scatter(y_test,predictions)

# %%
lm.score(x_train,y_train)
# Out:
# 0.842449119463877

# %%
lm.score(x_test,y_test)
# Out:
# 0.8422852322806889

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz,DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.ensemble import RandomForestRegressor

# %%
plt.figure(figsize=(5,5))
tree.plot_tree(dt,filled=True)

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.fit(x_test,y_test)
# Out:
# RandomForestRegressor()

# %%
predictionss =rf.predict(x_test)
plt.scatter(y_test,predictionss)

# %%
clf = DecisionTreeRegressor()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
clf.score(x_test,y_test)
# Out:
# 0.955952236428111

# %%
clf.score(x_train,y_train)
# Out:
# 0.9994260802508258

# %%
prediction = clf.predict(x_test)
plt.scatter(y_test,prediction)

# %%
rand_clf = RandomForestRegressor()

# %%
rand_clf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rand_clf.score(x_train,y_train)
# Out:
# 0.9968735213252924

# %%
rand_clf.score(x_test,y_test)
# Out:
# 0.9799082800001031

# %%
prediction = rand_clf.predict(x_test)
plt.scatter(y_test,prediction)
